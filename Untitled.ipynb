# %%
import sys
sys.path.insert(0, './frcnn/')

# %%
from test_frcnn3 import predict
# Out:
# Using TensorFlow backend.
# {0: 'traffic sign', 1: 'terrain', 2: 'vegetation', 3: 'car', 4: 'building', 5: 'sky', 6: 'pole', 7: 'road', 8: 'rider', 9: 'bicycle', 10: 'ego vehicle', 11: 'out of roi', 12: 'sidewalk', 13: 'cargroup', 14: 'fence', 15: 'traffic light', 16: 'person', 17: 'persongroup', 18: 'wall', 19: 'motorcycle', 20: 'bicyclegroup', 21: 'bus', 22: 'trailer', 23: 'motorcyclegroup', 24: 'parking', 25: 'truck', 26: 'ground', 27: 'rectification border', 28: 'rail track', 29: 'bridge', 30: 'train', 31: 'ridergroup', 32: 'traingroup', 33: 'caravan', 34: 'truckgroup', 35: 'guard rail', 36: 'busgroup', 37: 'tunnel', 38: 'bg'}

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
im1 = cv2.imread("../rando2.jpg")

# %%
im, bbxs = predict(im1)
# Out:
# (360, 640, 3)

# %%
plt.imshow(im)

# %%
bbxs
# Out:
# [['building', 848, 16, 1072, 256, 0.81140298],
#  ['building', -32, 32, 656, 368, 0.84328324],
#  ['pole', 960, 448, 976, 560, 0.82755619],
#  ['cargroup', 80, 384, 400, 512, 0.82835257],
#  ['sky', 560, 16, 768, 144, 0.91734308],
#  ['vegetation', 624, 288, 704, 384, 0.93946815]]

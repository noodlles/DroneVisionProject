# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import keras
import scipy.io as io

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
pc = io.loadmat("data/CBCL/CropData_128x128_bicycle_Pos_f001.mat")

# %%
plt.imshow(pc["grayX"][:, 66].reshape((128, 128)).T, cmap="gray")

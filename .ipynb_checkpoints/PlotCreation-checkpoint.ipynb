# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
RPNclassloss_dropclass = [0.503293431953,0.359186964259, 0.322369595904, 0.298752537608, 0.290164106194, 0.274368907396, 0.262807640061, 0.257282939546, 0.249014498204, 0.250030234717, 0.24523083454, 0.23122860894, 0.234542812429, 0.22348429236, 0.226451542027, 0.217266612371]
RPNregrloss_dropclass = [0.912900496162, 0.771304793358,0.71958633779, 0.654192882635, 0.629933276169, 0.584150575824, 0.561515896425, 0.552279003285, 0.533574513797,  0.527613097288, 0.522269903533, 0.507486698583, 0.505107688345, 0.483358007535, 0.496348850373, 0.482207106695 ]
CLclassloss_dropclass = [1.03532359546, 0.753601657569,0.756557390645, 0.641987117946, 0.577393543184, 0.581321626768, 0.55460608682,  0.556642912418, 0.533096595421, 0.525790841684, 0.531572949231, 0.530910588697, 0.507858775333, 0.516215322167, 0.511732958779, 0.517900928617 ]
CLregrloss_dropclass = [0.405066093192, 0.316113970377, 0.288622502625, 0.267056466915, 0.247741957478, 0.242306603536, 0.237261469387, 0.231633560687, 0.223307999998, 0.216226132128, 0.214854542378, 0.209262193672, 0.205332125377, 0.205979415797, 0.203894340206, 0.20675956488 ]
ClassAcc_dropclass =  [0.61465625, 0.6830625, 0.72715625, 0.7465, 0.75990625, 0.76240625, 0.76978125, 0.77146875, 0.783375, 0.7839375, 0.78215625, 0.78684375, 0.7915, 0.78828125, 0.7880625, 0.7846875]
totalloss_dropclass = [2.85658361677, 2.20020738556, 2.08713582696, 1.8619890051, 1.74523288302, 1.68214771352, 1.61619109269, 1.59783841594, 1.53899360742, 1.51966030582, 1.51392822968, 1.47888808989, 1.45284140148, 1.42903703786, 1.42413421256]
traintime_dropclass = [3361.34114909, 3335.58688617, 3315.7143569, 3334.0979919, 3319.80805707, 3315.2726171, 3357.19700384, 3343.36089802, 3327.29273891, 3336.32023382, 3324.51561999, 3319.59012794, 3365.12057805, 3354.32873011, 3350.05327392, 3307.89297891]
overlapRPN_dropclass = [23.189, 32.117, 36.506, 39.164, 40.3, 42.604, 44.661, 45.614, 45.679, 47.263, 47.269, 49.777, 49.877, 51.344, 51.555, 52.352]

# %%
RPNclassloss_dropres = [0.499267590091, 0.448439734742, .423530164182, 0.408372213237, 0.398406652614, 0.388947330475, 0.390091946959, 0.377597813047, 0.372433631793, 0.373136590213, 0.365186320722, 0.360739250258, 0.352365075089, 0.351915149435, 0.343833640143, 0.343861797772]
RPNregrloss_dropres = [0.935273987994, 0.877662481725, 0.847434091173, 0.856404043928, 0.854131225795, 0.817757511251, 0.814696289867, 0.79905746711, 0.769655374736, 0.766359242115, 0.742961619705, 0.738430962488, 0.732598816797, 0.715513547346, 0.714383454025, 0.70612090905]
CLclassloss_dropres = [1.14122837007, 0.889861577004, 0.814541936249, 0.773985978961, 0.70962424323, 0.699622573406, 0.682682370067,  0.668995517433, 0.668111588478, 0.65123487255, 0.631529422879, 0.631251606107, 0.619486879647, 0.619514254004, 0.618176173553, 0.624816679865]
CLregrloss_dropres = [0.419422616094, 0.35984073104, 0.336750265524, 0.31613846571, 0.292629177425, 0.285203867711, 0.27677353093, 0.274301712684, 0.265046709031, 0.258960026681, 0.246704615053, 0.250784012347, 0.243379916936, 0.239074318424, 0.237867290843, 0.237735678561]
ClassAcc_dropres =  [0.582375, 0.64596875, 0.67425, 0.689875, 0.707875, 0.7153125, 0.72040625, 0.73084375, 0.72771875,  0.73090625, .73846875, 0.739125, 0.74365625, 0.746375, 0.7501875, 0.74878125]
totalloss_dropres = [2.99519256425, 2.57580452451, 2.42225645713, 2.35490070184, 2.25479129906, 2.19153128284, 2.16424413782, 2.11995251027, 2.07524730404, 2.0496907315, 1.9863819783, 1.981205831, 1.94783068847, 1.92601726, 1.914260558, 1.9125350652]
traintime_dropres = [3028.62310195, 3005.02343893, 2990.79839206, 3040.86530399, 3048.01982498, 2989.69084001, 2974.827384, 2995.42369914, 3007.16880608, 3003.24491501, 2979.49549389, 3018.38818097, 3039.65476799, 3018.10842896, 3026.02279091, 3043.77677178]
overlapRPN_dropres = [22.012, 25.007, 27.48, 29.628, 29.099, 30.836, 31.738, 31.662, 32.69, 34.594, 35.517, 35.646, 36.03, 37.043,  37.917, 38.757]

# %%
RPNclassloss_narrow = [0.452611280091,0.332217, 0.298698379, 0.2888588, 0.2744, 0.2615, 0.25469, 0.24808, 0.23747, 0.23648, 0.22759, 0.21943, 0.21839, 0.21751, 0.22270, 0.21735]
RPNregrloss_narrow = [0.940932679363, 0.800109,0.71071, 0.64345, 0.60437, 0.58306, 0.56376,  0.54270, 0.52071, 0.52595, 0.50927, 0.49659, 0.49366, 0.49117, 0.49009, 0.48467 ]
CLclassloss_narrow = [0.96342, 0.70198,0.63842, 0.60606, 0.57673, 0.56175, 0.55588,  0.53952, 0.53583, 0.52398, 0.51404, 0.51626, 0.50429, 0.49767, 0.49287, 0.486079]
CLregrloss_narrow = [0.39736, 0.32483, 0.26904, 0.25991, 0.24000, 0.22892, 0.23122, 0.22244, 0.21827, 0.21378, 0.20877, 0.20468, 0.20482, 0.19691, 0.19431, 0.19358 ]
ClassAcc_narrow =  [0.6366875, 0.699125, 0.736, 0.74775, 0.75956, 0.76359, 0.76928, 0.77825, 0.77640, 0.78287, 0.78584, 0.78696, 0.79009, 0.79359, 0.79734, 0.80228]
totalloss_narrow = [2.7543373, 2.159144, 1.91687, 1.79829, 1.69554, 1.63528, 1.60558, 1.55275, 1.51230, 1.50021, 1.45968, 1.43697, 1.42118, 1.40327, 1.39998, 1.38168]
traintime_narrow = [3467.06, 3501.58688617, 3521.7143569, 3455.0979919, 3423.80805707, 3446.2726171, 3500.19700384, 3472.36089802, 3411.29273891, 3490.32023382, 3494.51561999, 3452.59012794, 3460.12057805, 3432.32873011, 3414.05327392, 3470.89297891]
overlapRPN_narrow = [25.545, 33.79, 43.08, 47.234, 49.539, 51.514, 52.436, 53.446, 54.781, 54.899, 55.432, 57.083, 57.347, 56.798, 56.446, 56.612]

# %%
RPNclassloss_base = [0.447441762418 , 0.331634428225, 0.300753973573 , 0.284013536401, 0.266878011674, 0.258307405859, 0.254254140556, 0.243619477902   , 0.240030475713, 0.236392180014, 0.229717662613, 0.22513582202, 0.221220851224, 0.220678295556, 0.217761119653, 0.212255512707]
RPNregrloss_base = [0.935844652608 ,  0.770737874791   , .692368160017  , 0.655491331339, 0.613132366456, 0.577812087871, 0.54542385928, 0.544978327885 , 0.540798516028 , 0.516364646502, 0.50781460283, 0.489756846026, 0.500615363955, 0.482019430436, 0.477721781295, 0.492098121267]
CLclassloss_base = [ 0.917861248314, 0.670657544464,  0.615697576851, 0.560554360151, 0.548473992512, 0.537145372272, 0.537830770791, 0.528682751819, 0.507349610955, 0.516756885052, 0.513142515764, 0.504118955523, 0.483374860212,  0.481688757941,  0.483656895235, 0.483061645672]
CLregrloss_base = [0.38538816572, 0.321901364453, 0.269846934371, 0.248945848014, 0.233180239275, 0.227144216027, 0.225881807238, 0.21375279532, 0.210788280088, 0.210695081756, 0.204818407759,  0.199664459266,  0.196662819363, 0.194266237222,  0.194003379025, 0.193877931487]
ClassAcc_base =  [0.66034375, 0.72740625, 0.74434375, 0.771625, 0.7739375, 0.77796875, 0.776375, 0.7861875, 0.789875, 0.790875, 0.787875, 0.787875, 0.79878125, 0.802625, 0.80040625, 0.80184375]
totalloss_base = [2.68653582906, 2.09493121193, 1.74900507591, 1.66166460992, 1.60040908203,  1.5633905778, 1.53103335293, 1.49896688278, 1.4802087933, 1.45549318897, 1.41867608283, 1.4018738947, 1.37865272116, 1.3731431752, 1.35796024473]
traintime_base = [3500.06638408,3422.66632199,3462.6843748,3436.98474288,3444.55164504,3460.11020112,3425.12634516,3380.39053297,3458.86417603,3489.5368280,3462.19033813,3449.95801711,3478.41112518,3373.1783421,3382.14638019,3435.37340808]
overlapRPN_base = [ 23.443, 29.032, 36.593, 40.534, 43.032, 45.604, 47.751, 48.183, 50.542, 51.132, 51.217, 53.38, 53.103, 53.25, 53.878, 53.638]

# %%
plt.plot(RPNclassloss_dropclass, label="Shallow Classifier")
plt.plot(RPNclassloss_dropres, label="Shallow NN Base")
plt.plot(RPNclassloss_narrow, label="Narrow NN Base")
plt.plot(RPNclassloss_base, label="Standard Model")
plt.ylabel("RPN Classification Loss")
plt.xlabel("Epoch #")
plt.legend()
plt.savefig("RPNclassloss.jpg")
plt.show()

# %%
plt.plot(RPNregrloss_dropclass, label="Shallow Classifier")
plt.plot(RPNregrloss_dropres, label="Shallow NN Base")
plt.plot(RPNregrloss_narrow, label="Narrow NN Base")
plt.plot(RPNregrloss_base, label="Standard Model")
plt.ylabel("RPN Regression Loss")
plt.xlabel("Epoch #")
plt.legend()
plt.show()

# %%
plt.plot(CLregrloss_dropclass, label="Shallow Classifier")
plt.plot(CLregrloss_dropres, label="Shallow NN Base")
plt.plot(CLregrloss_narrow, label="Narrow NN Base")
plt.plot(CLregrloss_base, label="Standard Model")
plt.ylabel("Classifier Regression Loss")
plt.xlabel("Epoch #")
plt.legend()
plt.show()

# %%
plt.plot(CLclassloss_dropclass, label="Shallow Classifier")
plt.plot(CLclassloss_dropres, label="Shallow NN Base")
plt.plot(CLclassloss_narrow, label="Narrow NN Base")
plt.plot(CLclassloss_base, label="Standard Model")
plt.ylabel("Classifier Classification Loss")
plt.xlabel("Epoch #")
plt.legend()
plt.show()

# %%
plt.plot(ClassAcc_dropclass, label="Shallow Classifier")
plt.plot(ClassAcc_dropres, label="Shallow NN Base")
plt.plot(ClassAcc_narrow, label="Narrow NN Base")
plt.plot(ClassAcc_base, label="Standard Model")
plt.ylabel("Object Classification Accuracy")
plt.xlabel("Epoch #")
plt.legend(loc="lower right")
plt.show()

# %%
plt.plot(totalloss_dropclass, label="Shallow Classifier")
plt.plot(totalloss_dropres, label="Shallow NN Base")
plt.plot(totalloss_narrow, label="Narrow NN Base")
plt.plot(totalloss_base, label="Standard Model")
plt.ylabel("Total Loss")
plt.xlabel("Epoch #")
plt.legend()
plt.show()

# %%
# plt.plot(traintime_dropclass, label="Shallow Classifier")
# plt.plot(traintime_dropres, label="Shallow NN Base")
# plt.plot(traintime_narrow, label="Narrow NN Base")
# plt.plot(traintime_base, label="Standard Model")
plt.boxplot([traintime_dropclass, traintime_dropres, traintime_narrow, traintime_base], labels=["ShallowClassifier", "ShallowNNBase", "NarrowNNBase", "StandardModel"])
plt.ylabel("Training Time (s) per epoch")
plt.xlabel("Model")
plt.legend()
plt.show()

# %%
plt.plot(overlapRPN_dropclass, label="Shallow Classifier")
plt.plot(overlapRPN_dropres, label="Shallow NN Base")
plt.plot(overlapRPN_narrow, label="Narrow NN Base")
plt.plot(overlapRPN_base, label="Standard Model")
plt.xlabel("Epoch #")
plt.ylabel("Mean # Overlapping Bounding Boxes")
plt.legend(loc="lower right")
plt.show()

# %%
predtime_dropclass = np.loadtxt("times_shallowclassifier.txt")
predtime_dropres = np.loadtxt("times_shallownn.txt")
predtime_base = np.loadtxt("times_base.txt")
predtime_narrow = np.loadtxt("times_narrow.txt")
plt.boxplot([predtime_dropclass, predtime_dropres, predtime_narrow, predtime_base], labels=["ShallowClassifier", "ShallowNNBase", "NarrowNNBase", "StandardModel"])
plt.ylabel("Testing Time (s)")
plt.xlabel("Model")
plt.legend()
plt.show()
